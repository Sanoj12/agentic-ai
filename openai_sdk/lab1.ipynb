# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from groq import Groq

# %%
load_dotenv(override=True)
client=Groq(api_key="GROQ_API_KEY")

# %%
agent = Agent(name="jokester" , instructions="you are a joker teller" , model="openai/gpt-oss-20b")

# %%
agent
# Out:
# Agent(name='jokester', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='you are a joker teller', prompt=None, handoffs=[], model='openai/gpt-oss-20b', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
prompt="telling about ai"
result = await Runner.run(agent,prompt) 

print(result(prompt))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[19], line 2
#       1 prompt="telling about ai"
# ----> 2 result = await Runner.run(agent,prompt)
#       4 print(result(prompt))
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:343, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     294 """
#     295 Run a workflow starting at the given agent.
#     296
#    (...)
#     339     type of the output.
#     340 """
#     342 runner = DEFAULT_AGENT_RUNNER
# --> 343 return await runner.run(
#     344     starting_agent,
#     345     input,
#     346     context=context,
#     347     max_turns=max_turns,
#     348     hooks=hooks,
#     349     run_config=run_config,
#     350     previous_response_id=previous_response_id,
#     351     conversation_id=conversation_id,
#     352     session=session,
#     353 )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:602, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     597 logger.debug(
#     598     f"Running agent {current_agent.name} (turn {current_turn})",
#     599 )
#     601 if current_turn == 1:
# --> 602     input_guardrail_results, turn_result = await asyncio.gather(
#     603         self._run_input_guardrails(
#     604             starting_agent,
#     605             starting_agent.input_guardrails
#     606             + (run_config.input_guardrails or []),
#     607             _copy_str_or_list(prepared_input),
#     608             context_wrapper,
#     609         ),
#     610         self._run_single_turn(
#     611             agent=current_agent,
#     612             all_tools=all_tools,
#     613             original_input=original_input,
#     614             generated_items=generated_items,
#     615             hooks=hooks,
#     616             context_wrapper=context_wrapper,
#     617             run_config=run_config,
#     618             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     619             tool_use_tracker=tool_use_tracker,
#     620             server_conversation_tracker=server_conversation_tracker,
#     621         ),
#     622     )
#     623 else:
#     624     turn_result = await self._run_single_turn(
#     625         agent=current_agent,
#     626         all_tools=all_tools,
#    (...)
#     634         server_conversation_tracker=server_conversation_tracker,
#     635     )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:1417, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker)
#    1414     input = ItemHelpers.input_to_new_input_list(original_input)
#    1415     input.extend([generated_item.to_input_item() for generated_item in generated_items])
# -> 1417 new_response = await cls._get_new_response(
#    1418     agent,
#    1419     system_prompt,
#    1420     input,
#    1421     output_schema,
#    1422     all_tools,
#    1423     handoffs,
#    1424     hooks,
#    1425     context_wrapper,
#    1426     run_config,
#    1427     tool_use_tracker,
#    1428     server_conversation_tracker,
#    1429     prompt_config,
#    1430 )
#    1432 return await cls._get_single_step_result_from_response(
#    1433     agent=agent,
#    1434     original_input=original_input,
#    (...)
#    1443     tool_use_tracker=tool_use_tracker,
#    1444 )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:1644, in AgentRunner._get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config)
#    1619 @classmethod
#    1620 async def _get_new_response(
#    1621     cls,
#    (...)
#    1634 ) -> ModelResponse:
#    1635     # Allow user to modify model input right before the call, if configured
#    1636     filtered = await cls._maybe_filter_model_input(
#    1637         agent=agent,
#    1638         run_config=run_config,
#    (...)
#    1641         system_instructions=system_prompt,
#    1642     )
# -> 1644     model = cls._get_model(agent, run_config)
#    1645     model_settings = agent.model_settings.resolve(run_config.model_settings)
#    1646     model_settings = RunImpl.maybe_reset_tool_choice(agent, tool_use_tracker, model_settings)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:1749, in AgentRunner._get_model(cls, agent, run_config)
#    1746 elif isinstance(agent.model, Model):
#    1747     return agent.model
# -> 1749 return run_config.model_provider.get_model(agent.model)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\models\multi_provider.py:144, in MultiProvider.get_model(self, model_name)
#     142     return provider.get_model(model_name)
#     143 else:
# --> 144     return self._get_fallback_provider(prefix).get_model(model_name)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\models\openai_provider.py:87, in OpenAIProvider.get_model(self, model_name)
#      84 if model_name is None:
#      85     model_name = get_default_model()
# ---> 87 client = self._get_client()
#      89 return (
#      90     OpenAIResponsesModel(model=model_name, openai_client=client)
#      91     if self._use_responses
#      92     else OpenAIChatCompletionsModel(model=model_name, openai_client=client)
#      93 )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\models\openai_provider.py:73, in OpenAIProvider._get_client(self)
#      71 def _get_client(self) -> AsyncOpenAI:
#      72     if self._client is None:
# ---> 73         self._client = _openai_shared.get_default_openai_client() or AsyncOpenAI(
#      74             api_key=self._stored_api_key or _openai_shared.get_default_openai_key(),
#      75             base_url=self._stored_base_url,
#      76             organization=self._stored_organization,
#      77             project=self._stored_project,
#      78             http_client=shared_http_client(),
#      79         )
#      81     return self._client
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# OPENAI_API_KEY is not set, skipping trace export

# %%
with trace("telling a joke"):
    result =await Runner.run(agent,"tell a joke about automonous ai agents")
    print(result)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 with trace("telling a joke"):
# ----> 2     result =await Runner.run(agent,"tell a joke about automonous ai agents")
#       3     print(result)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:343, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     294 """
#     295 Run a workflow starting at the given agent.
#     296
#    (...)
#     339     type of the output.
#     340 """
#     342 runner = DEFAULT_AGENT_RUNNER
# --> 343 return await runner.run(
#     344     starting_agent,
#     345     input,
#     346     context=context,
#     347     max_turns=max_turns,
#     348     hooks=hooks,
#     349     run_config=run_config,
#     350     previous_response_id=previous_response_id,
#     351     conversation_id=conversation_id,
#     352     session=session,
#     353 )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:602, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     597 logger.debug(
#     598     f"Running agent {current_agent.name} (turn {current_turn})",
#     599 )
#     601 if current_turn == 1:
# --> 602     input_guardrail_results, turn_result = await asyncio.gather(
#     603         self._run_input_guardrails(
#     604             starting_agent,
#     605             starting_agent.input_guardrails
#     606             + (run_config.input_guardrails or []),
#     607             _copy_str_or_list(prepared_input),
#     608             context_wrapper,
#     609         ),
#     610         self._run_single_turn(
#     611             agent=current_agent,
#     612             all_tools=all_tools,
#     613             original_input=original_input,
#     614             generated_items=generated_items,
#     615             hooks=hooks,
#     616             context_wrapper=context_wrapper,
#     617             run_config=run_config,
#     618             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     619             tool_use_tracker=tool_use_tracker,
#     620             server_conversation_tracker=server_conversation_tracker,
#     621         ),
#     622     )
#     623 else:
#     624     turn_result = await self._run_single_turn(
#     625         agent=current_agent,
#     626         all_tools=all_tools,
#    (...)
#     634         server_conversation_tracker=server_conversation_tracker,
#     635     )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:1417, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker)
#    1414     input = ItemHelpers.input_to_new_input_list(original_input)
#    1415     input.extend([generated_item.to_input_item() for generated_item in generated_items])
# -> 1417 new_response = await cls._get_new_response(
#    1418     agent,
#    1419     system_prompt,
#    1420     input,
#    1421     output_schema,
#    1422     all_tools,
#    1423     handoffs,
#    1424     hooks,
#    1425     context_wrapper,
#    1426     run_config,
#    1427     tool_use_tracker,
#    1428     server_conversation_tracker,
#    1429     prompt_config,
#    1430 )
#    1432 return await cls._get_single_step_result_from_response(
#    1433     agent=agent,
#    1434     original_input=original_input,
#    (...)
#    1443     tool_use_tracker=tool_use_tracker,
#    1444 )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:1644, in AgentRunner._get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config)
#    1619 @classmethod
#    1620 async def _get_new_response(
#    1621     cls,
#    (...)
#    1634 ) -> ModelResponse:
#    1635     # Allow user to modify model input right before the call, if configured
#    1636     filtered = await cls._maybe_filter_model_input(
#    1637         agent=agent,
#    1638         run_config=run_config,
#    (...)
#    1641         system_instructions=system_prompt,
#    1642     )
# -> 1644     model = cls._get_model(agent, run_config)
#    1645     model_settings = agent.model_settings.resolve(run_config.model_settings)
#    1646     model_settings = RunImpl.maybe_reset_tool_choice(agent, tool_use_tracker, model_settings)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\run.py:1749, in AgentRunner._get_model(cls, agent, run_config)
#    1746 elif isinstance(agent.model, Model):
#    1747     return agent.model
# -> 1749 return run_config.model_provider.get_model(agent.model)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\models\multi_provider.py:144, in MultiProvider.get_model(self, model_name)
#     142     return provider.get_model(model_name)
#     143 else:
# --> 144     return self._get_fallback_provider(prefix).get_model(model_name)
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\models\openai_provider.py:87, in OpenAIProvider.get_model(self, model_name)
#      84 if model_name is None:
#      85     model_name = get_default_model()
# ---> 87 client = self._get_client()
#      89 return (
#      90     OpenAIResponsesModel(model=model_name, openai_client=client)
#      91     if self._use_responses
#      92     else OpenAIChatCompletionsModel(model=model_name, openai_client=client)
#      93 )
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\agents\models\openai_provider.py:73, in OpenAIProvider._get_client(self)
#      71 def _get_client(self) -> AsyncOpenAI:
#      72     if self._client is None:
# ---> 73         self._client = _openai_shared.get_default_openai_client() or AsyncOpenAI(
#      74             api_key=self._stored_api_key or _openai_shared.get_default_openai_key(),
#      75             base_url=self._stored_base_url,
#      76             organization=self._stored_organization,
#      77             project=self._stored_project,
#      78             http_client=shared_http_client(),
#      79         )
#      81     return self._client
#
# File c:\Users\sanoj\anaconda_new\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
# OPENAI_API_KEY is not set, skipping trace export
